# %% [markdown]
# # Cleaning Practice
# Let's first practice handling missing values and duplicate data using the `cancer_data_means.csv` file.

# %%
#import libraries and assign cancer_data_means.csv to a variable 
import pandas as pd
import numpy as np
df = pd.read_csv('cancer_data_means.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99           NaN          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3                NaN           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  fractal_dimension_mean
# 0           0.2419                 0.07871
# 1           0.1812                 0.05667
# 2           0.2069                 0.05999
# 3           0.2597                 0.09744
# 4           0.1809                 0.05883
# ..             ...                     ...
# 564         0.1726                 0.05623
# 565         0.1752                 0.05533
# 566         0.1590                 0.05648
# 567         0.2397                 0.07016
# 568         0.1587                 0.05884
#
# [569 rows x 12 columns]

# %%
# check which columns have missing values
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean              21
# perimeter_mean             0
# area_mean                  0
# smoothness_mean           48
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean             65
# fractal_dimension_mean     0
# dtype: int64

# %%
for col in df.columns:
    print(f"{col} {round(df[col].isna().mean()*100,2)}%")
# Out:
# id 0.0%
# diagnosis 0.0%
# radius_mean 0.0%
# texture_mean 3.69%
# perimeter_mean 0.0%
# area_mean 0.0%
# smoothness_mean 8.44%
# compactness_mean 0.0%
# concavity_mean 0.0%
# concave_points_mean 0.0%
# symmetry_mean 11.42%
# fractal_dimension_mean 0.0%

# %%
df.dtypes
# Out:
# id                          int64
# diagnosis                  object
# radius_mean               float64
# texture_mean              float64
# perimeter_mean            float64
# area_mean                 float64
# smoothness_mean           float64
# compactness_mean          float64
# concavity_mean            float64
# concave_points_mean       float64
# symmetry_mean             float64
# fractal_dimension_mean    float64
# dtype: object

# %%
df[['texture_mean','smoothness_mean','symmetry_mean']] = df[['texture_mean','smoothness_mean','symmetry_mean']].fillna(df[['texture_mean','smoothness_mean','symmetry_mean']].median())

# %%
# confirm your correction
df.isna().sum()
# Out:
# id                        0
# diagnosis                 0
# radius_mean               0
# texture_mean              0
# perimeter_mean            0
# area_mean                 0
# smoothness_mean           0
# compactness_mean          0
# concavity_mean            0
# concave_points_mean       0
# symmetry_mean             0
# fractal_dimension_mean    0
# dtype: int64

# %%
# how many duplicates are there ?
df.duplicated().sum()
# Out:
# 5

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# confirm correction by rechecking for duplicates in the data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Renaming Columns
# Since we also previously changed our dataset to only include means of tumor features, the "_mean" at the end of each feature seems unnecessary. It just takes extra time to type in our analysis later. Rename the columns of the dataframe to remove "_mean".

# %%
# rename the columns of the dataframe (remove _mean from the name of each column if found)
df.columns = df.columns.str.replace('_mean','')
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean'],
#       dtype='object')

# %%
# display first few rows of the dataframe to confirm changes
df.head(10)
# Out:
#          id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0    842302         M   17.99   18.785     122.80  1001.0     0.11840
# 1    842517         M   20.57   17.770     132.90  1326.0     0.08474
# 2  84300903         M   19.69   21.250     130.00  1203.0     0.10960
# 3  84348301         M   11.42   20.380      77.58   386.1     0.09578
# 4  84358402         M   20.29   14.340     135.10  1297.0     0.10030
# 5    843786         M   12.45   15.700      82.57   477.1     0.12780
# 6    844359         M   18.25   19.980     119.60  1040.0     0.09463
# 7  84458202         M   13.71   20.830      90.20   577.9     0.11890
# 8    844981         M   13.00   21.820      87.50   519.8     0.12730
# 9  84501001         M   12.46   24.040      83.97   475.9     0.11860
#
#    compactness  concavity  concave_points  symmetry  fractal_dimension
# 0      0.27760    0.30010         0.14710   0.24190            0.07871
# 1      0.07864    0.08690         0.07017   0.18120            0.05667
# 2      0.15990    0.19740         0.12790   0.20690            0.05999
# 3      0.28390    0.24140         0.10520   0.25970            0.09744
# 4      0.13280    0.19800         0.10430   0.18090            0.05883
# 5      0.17000    0.15780         0.08089   0.20870            0.07613
# 6      0.10900    0.11270         0.07400   0.17895            0.05742
# 7      0.16450    0.09366         0.05985   0.21960            0.07451
# 8      0.19320    0.18590         0.09353   0.23500            0.07389
# 9      0.23960    0.22730         0.08543   0.20300            0.08243

# %%
# save this for later as a csv file named "cancer_data_edited.csv" and set indexing to false (why ??)
df.to_csv("cancer_data_edited.csv" , index = False)
